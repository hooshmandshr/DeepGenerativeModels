# %%
import matplotlib.pyplot as plt

import numpy as np
import os

os.environ["CUDA_VISIBLE_DEVICES"]="-1"

import tensorflow as tf

from norm_flow import PlanarFlow, TimeAutoRegressivePlanarFlow
from distribution import BlockTriDiagonalNormal
from transform import *
from model import *

from utils.test_block_matrix import *
from utils.block_matrix import *

# %%
N_SAMPLE = 1000

with tf.Graph().as_default():
    a = np.random.rand(100, 10)
    model = ReparameterizedDistribution(
        out_dim=2, in_dim=10,
        distribution=tf.contrib.distributions.Poisson,
        transform=LinearTransform)

    y = tf.constant(np.random.rand(2, 10))
    x = model.sample(y=y, n_samples=N_SAMPLE)
    print x.shape
    p = model.log_prob(x=x, y=y)
    e = p#model.entropy(y=y)
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        x_, p_, e_ = sess.run([x, p, e])
# Out:
# (1000, 2, 2)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-aa87fa06c085> in <module>()
#      15     with tf.Session() as sess:
#      16         sess.run(tf.global_variables_initializer())
# ---> 17         x_, p_ = sess.run([x, p])
#
# /home/hooshmand/Documents/VAE/gpuenv/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/hooshmand/Documents/VAE/gpuenv/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
# ...

# %%
x_.shape, p_.shape, e_.shape
# Out:
# ((1000, 2, 2), (1000, 2), (2,))

# %%
for i in range(2):
    plt.scatter(x_[:, i, 0], x_[:, i, 1], s=4)

# %%
with tf.Graph().as_default():
    a = np.random.rand(100, 10)
    mlp = MultiLayerPerceptron(in_dim=10, out_dim=2, hidden_units=[30, 20])
    y = mlp.operator(a)
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        out = sess.run(y)

# %%
plt.scatter(a[:, 0], a[:, 1])
plt.scatter(out[:, 0], out[:, 1])

# %%
time, dim = 3, 2
dtype = np.float32
loc_ = np.random.rand(time * dim).astype(dtype)
inv_cov_d = np.random.rand(time, dim, dim)
inv_cov_d += inv_cov_d.transpose([0, 2, 1])
inv_cov_d /= 2.
inv_cov_d += np.eye(dim)[None, :, :] #* dim #* time
inv_cov_d = inv_cov_d.astype(dtype)

inv_cov_o = np.random.rand(time - 1, dim, dim).astype(dtype)

dense_inv_cov = dense_matrix(inv_cov_d, inv_cov_o, tridiagonal=True)
plt.imshow(dense_inv_cov)

# %%
N = 10000
with tf.Graph().as_default():
    btm = BlockTriDiagonalMatrix(
        diag_block=tf.constant(inv_cov_d),
        offdiag_block=tf.constant(inv_cov_o))
    dist = BlockTriDiagonalNormal(loc=loc_, inv_cov=btm)
    e = dist.entropy()
    s = dist.sample(N)
    with tf.Session() as sess:
        s_ = sess.run(s)
        e_ = sess.run(e)

# %%
import scipy.stats
real_s = np.random.multivariate_normal(loc_, np.linalg.inv(dense_inv_cov), N)
real_ent = scipy.stats.multivariate_normal(loc_, np.linalg.inv(dense_inv_cov)).entropy()

# %%
print e_
print real_ent
# Out:
# 8.334313
# 8.334313974924624

# %%
dim1, dim2 = 0, 4
lim_ = 7
for i in range(dim * time):
    for j in range(dim * time):
        dim1, dim2 = i, j
        plt.scatter(real_s[:, dim1], real_s[:, dim2])
        plt.scatter(s_[:, dim1], s_[:, dim2])
        plt.ylim(-lim_, lim_)
        plt.xlim(-lim_, lim_)
        plt.gcf().set_size_inches(10, 10)
        plt.show()
